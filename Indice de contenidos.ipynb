# %% [markdown]
# # INDICE DE CONTENIDOS
# -------
#
# ## Carpetas del repositorio
# ___
# ### Carpeta Archivos
# - apertura archivos.ipynb
# kaggle.csv/ data.csv/data.xml/data.txt
# - data_remaning_kaggle.csv
# archivo original
# - data_txt_clean.txt
# archivo original
# - data_xml_clean.xml
# archivo original
# - df_sum_herramientas.csv
# archivo original
# - exported_db_data.csv
# archivo original
# - kaggle_survey_2021_answer_choices.pdf
# Encuesta
# - noprof.csv
# resulta de data_remaning_kaggle.csv
# - notebooks.csv
# resulta de exported_db_data.csv
# - platform.csv
# resulta del kaggle
# - txt_limpio.csv
# - union_datos.csv
# archivos txt y xml unificados
# - xml_limpio.csv
#
# ### Carpeta Exploracion_unificación
# Esta carpeta contiene el código para la exploración y unificación de cada archivo correspondiente
#
# ### Carpeta Limpieza
# - limpieza.ipynb
# contiene código para la limpieza de datos del archivo union_datos
# - union_datos.csv
# archivo resultante
#
#
#
# ## Archivos desechados y su procendencia
# De momento hemos desechado:
#
#
# | TEMAS | PREGUNTAS  | ARCHIVO
# | --- | --- | --- |
# | herramientas de machine learning | q34, q35 | TXT |
# | herramientas de business intelligence | q33 | TXT |
# | procesado de imágenes | q18 | KAGGLE |
# | lenguaje natural de procesado (NLP) | q19 |KAGGLE|
# |Plataformas en la nube. Sólo respuestas irrelevantes|q27|KAGGLE
# |herramientas de machine learning|q34, q35 |TXT|
# |con qué plataformas( de q27) estás familiarizado. Sólo respuestas irrelevantes|q28|KAGGLE
# |productos de almacenamiento de datos|q30|KAGGLE
# |herramientas de gestión de experimentos de ML|q38|KAGGLE
# |notebooks.Hemos quitado solamente respuestas irrelevantes.|q10 |CSV|
# |columna  ‘0’ y ‘time’|‘level 0’ y columna ‘time’|XML
# |plataformas en la nube que usas habitualmente|q27| KAGGLE
#
#
# ## Nombre de columnas del archivo union_datos
#
#
# age
#
# gender
#
# pais
#
# estudios
#
# puesto_trabajo
#
# experiencia
#
# lenguaje_recomendado
#
# experiencia_ML
#
# industria
#
# tamaño_empresa
#
# salario
#
# herramienta_DA
#
# lenguaje_utilizado
#
# IDE
#
# herramientas visualizacion
#
# Q16
#
# Q17
#
# Q32
#
# Q34
#
# kaggle
#
# colab
#
# ninguno
#
# Q27_A_Part__1
#
# Q27_A_Part__2
#
# Q27_A_Part_3
#
# Q27_A_Part_4
#
# Q27_A_Part_5
#
# Q27_A_Part_6
#
# Q27_Ä_Part_7
#
# Q27_A_Part_8
#
# Q27_A_Part_9
#
# Q27_A_Part_10
#
# Q27_A_Part_11
#
# Q27_A_OTHER
#
# Q28
#
# Q39_Part_1
#
# Q39_Part_2
#
# Q39_Part_3
#
# Q39_Part_4
#
# Q39_Part_9
#
# Q39_OTHER
#
# Q40_Part_1
#
# Q40_Part_2
#
# Q40_Part_3
#
# Q40_Part_4
#
# Q40_Part_5
#
# Q40_Part_6
#
# Q40_Part_7
#
# Q40_Part_8
#
# Q40_Part_9
#
# Q40_Part_10
#
# Q40_Part_11
#
# Q40_OTHER
#
# Q27_B_Part_1
#
# Q27_B_Part_2
#
# Q27_B_Part_3
#
# Q27_B_Part_4
#
# Q27_B_Part_5
#
# Q27_B_Part_6
#
# Q27_B_Part_7
#
# Q27_B_Part_8
#
# Q27_B_Part_9
#
# Q27_B_Part_10
#
# Q27_B_Part_11
#
# Q27_B_OTHER
#
# Q29_B_Part_1
#
# Q29_B_Part_2
#
# Q29_B_Part_3
#
# Q29_B_Part_4
#
# Q29_B_OTHER
#
# Q31_B_Part_1
#
# Q31_B_Part_2
#
# Q31_B_Part_3
#
# Q31_B_Part_4
#
# Q31_B_Part_5
#
# Q31_B_Part_6
#
# Q31_B_Part_7
#
# Q31_B_Part_8
#
# Q31_B_Part_9
#
# Q31_B_OTHER
#
# Q32_B_Part_1
#
# Q32_B_Part_2
#
# Q32_B_Part_3
#
# Q32_B_Part_4
#
# Q32_B_Part_5
#
# Q32_B_Part_6
#
# Q32_B_Part_7
#
# Q32_B_Part_8
#
# Q32_B_Part_9
#
# Q32_B_Part_10
#
# Q32_B_Part_11
#
# Q32_B_Part_12
#
# Q32_B_Part_13
#
# Q32_B_Part_14
#
# Q32_B_Part_15
#
# Q32_B_Part_16
#
# Q32_B_Part_17
#
# Q32_B_Part_18
#
# Q32_B_Part_19
#
# Q32_B_Part_20
#
# Q32_B_OTHER
#
# Q34_B_Part_1
#
# Q34_B_Part_2
#
# Q34_B_Part_3
#
# Q34_B_Part_4
#
# Q34_B_Part_5
#
# Q34_B_Part_6
#
# Q34_B_Part_7
#
# Q34_B_Part_8
#
# Q34_B_Part_9
#
# Q34_B_Part_10
#
# Q34_B_Part_11
#
# Q34_B_Part_12
#
# Q34_B_Part_13
#
# Q34_B_Part_14
#
# Q34_B_Part_15
#
# Q34_B_Part_16
#
# Q34_B_OTHER
#
# Q36_B_Part_1
#
# Q36_B_Part_2
#
# Q36_B_Part_3
#
# Q36_B_Part_4
#
# Q36_B_Part_5
#
# Q36_B_Part_6
#
# Q36_B_Part_7
#
# Q36_B_OTHER
#
# Q37_B_Part_1
#
# Q37_B_Part_2
#
# Q37_B_Part_3
#
# Q37_B_Part_4
#
# Q37_B_Part_5
#
# Q37_B_Part_6
#
# Q37_B_Part_7
#
# Q37_B_OTHER
#
# Q38_B_Part_1
#
# Q38_B_Part_2
#
# Q38_B_Part_3
#
# Q38_B_Part_4
#
# Q38_B_Part_5
#
# Q38_B_Part_6
#
# Q38_B_Part_7
#
# Q38_B_Part_8
#
# Q38_B_Part_9
#
# Q38_B_Part_10
#
# Q38_B_Part_11
#
# Q38_B_OTHER
