# %%
import pandas as pd
pd.options.display.max_columns = None
import re
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sidetable

# %%
df = pd.read_csv("../Archivos/union_datos.csv")

# %%
df.columns
# Out:
# Index(['age', 'gender', 'pais', 'estudios', 'puesto_trabajo', 'experiencia',
#        'lenguaje_recomendado', 'experiencia_ML', 'industria', 'tamaño_empresa',
#        ...
#        'Q38_B_Part_3', 'Q38_B_Part_4', 'Q38_B_Part_5', 'Q38_B_Part_6',
#        'Q38_B_Part_7', 'Q38_B_Part_8', 'Q38_B_Part_9', 'Q38_B_Part_10',
#        'Q38_B_Part_11', 'Q38_B_OTHER'],
#       dtype='object', length=138)

# %%
df.head(3)
# Out:
#      age gender       pais           estudios           puesto_trabajo  \
# 0  50-54    Man      India  Bachelor’s degree                    Other
# 1  50-54    Man  Indonesia    Master’s degree  Program/Project Manager
# 2  22-24    Man   Pakistan    Master’s degree        Software Engineer
#
#   experiencia lenguaje_recomendado                         experiencia_ML  \
# 0  5-10 years               Python                             5-10 years
# 1   20+ years               Python                               < 1 year
# 2   1-3 years               Python  I do not use machine learning methods
#
#                    industria        tamaño_empresa        salario  \
# 0  Manufacturing/Fabrication      50-249 employees  25,000-29,999
# 1  Manufacturing/Fabrication  1000-9,999 employees  60,000-69,999
# 2        Academics/Education  1000-9,999 employees         $0-999
#
#                                       herramienta_DA  lenguaje_utilizado  \
# 0  Local development environments (RStudio, Jupyt...           Python, R
# 1    Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
# 2  Basic statistical software (Microsoft Excel, G...   Python, C++, Java
#
#                                 IDE  \
# 0                       Vim / Emacs
# 1        Notepad++,Jupyter Notebook
# 2  PyCharm ,Jupyter Notebook, Other
#
#                           herramientas_visualizacion  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
# 1                                        Matplotlib
# 2                                        Matplotlib
#
#                                  Q16  \
# 0  Scikit-learn , TensorFlow ,Caret
# 1                      Scikit-learn
# 2                                NaN
#
#                                                  Q17               Q32    Q34  \
# 0  Linear or Logistic Regression, Decision Trees ...       PostgreSQL    None
# 1  Linear or Logistic Regression, Decision Trees ...               NaN    NaN
# 2                                                NaN  MySQL , MongoDB    None
#
#           Q10_kaggle        Q10_colab Q10_none  Q28 Q39_Part_1 Q39_Part_2  \
# 0                NaN  Colab Notebooks      NaN  NaN        NaN        NaN
# 1   Kaggle Notebooks  Colab Notebooks      NaN  NaN        NaN        NaN
# 2   Kaggle Notebooks              NaN      NaN  NaN        NaN        NaN
#
#   Q39_Part_3 Q39_Part_4 Q39_Part_5 Q39_Part_6 Q39_Part_7 Q39_Part_8  \
# 0        NaN    GitHub         NaN    Kaggle         NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
#
#                         Q39_Part_9 Q39_OTHER Q40_Part_1 Q40_Part_2  \
# 0                              NaN       NaN   Coursera        edX
# 1                              NaN       NaN        NaN        NaN
# 2  I do not share my work publicly       NaN        NaN        NaN
#
#              Q40_Part_3 Q40_Part_4 Q40_Part_5 Q40_Part_6 Q40_Part_7  \
# 0  Kaggle Learn Courses   DataCamp        NaN    Udacity      Udemy
# 1  Kaggle Learn Courses        NaN        NaN        NaN        NaN
# 2                   NaN   DataCamp        NaN        NaN        NaN
#
#   Q40_Part_8                                         Q40_Part_9  \
# 0        NaN                                                NaN
# 1        NaN  Cloud-certification programs (direct from AWS,...
# 2        NaN                                                NaN
#
#                                          Q40_Part_10 Q40_Part_11 Q40_OTHER  \
# 0                                                NaN         NaN       NaN
# 1  University Courses (resulting in a university ...         NaN       NaN
# 2                                                NaN         NaN       NaN
#
#                   Q27_B_Part_1 Q27_B_Part_2                   Q27_B_Part_3  \
# 0                          NaN          NaN                            NaN
# 1                          NaN          NaN   Google Cloud Platform (GCP)
# 2   Amazon Web Services (AWS)           NaN   Google Cloud Platform (GCP)
#
#   Q27_B_Part_4    Q27_B_Part_5 Q27_B_Part_6 Q27_B_Part_7 Q27_B_Part_8  \
# 0          NaN             NaN          NaN          NaN          NaN
# 1          NaN   Oracle Cloud           NaN          NaN          NaN
# 2          NaN             NaN          NaN          NaN          NaN
#
#   Q27_B_Part_9 Q27_B_Part_10 Q27_B_Part_11 Q27_B_OTHER Q29_B_Part_1  \
# 0          NaN           NaN           NaN         NaN          NaN
# 1          NaN           NaN           NaN         NaN          NaN
# 2          NaN           NaN           NaN         NaN          NaN
#
#                          Q29_B_Part_2                   Q29_B_Part_3  \
# 0                                 NaN                            NaN
# 1                                 NaN   Google Cloud Compute Engine
# 2   Microsoft Azure Virtual Machines    Google Cloud Compute Engine
#
#   Q29_B_Part_4 Q29_B_OTHER Q31_B_Part_1                     Q31_B_Part_2  \
# 0          NaN         NaN          NaN                              NaN
# 1          NaN         NaN          NaN                              NaN
# 2          NaN         NaN          NaN   Azure Machine Learning Studio
#
#               Q31_B_Part_3 Q31_B_Part_4 Q31_B_Part_5 Q31_B_Part_6  \
# 0                      NaN          NaN          NaN          NaN
# 1                      NaN          NaN          NaN          NaN
# 2   Google Cloud Vertex AI    DataRobot          NaN          NaN
#
#   Q31_B_Part_7 Q31_B_Part_8 Q31_B_Part_9 Q31_B_OTHER Q32_B_Part_1  \
# 0          NaN          NaN          NaN         NaN          NaN
# 1          NaN          NaN         None         NaN       MySQL
# 2          NaN          NaN          NaN         NaN       MySQL
#
#   Q32_B_Part_2 Q32_B_Part_3      Q32_B_Part_4 Q32_B_Part_5 Q32_B_Part_6  \
# 0          NaN          NaN               NaN          NaN          NaN
# 1          NaN      SQLite   Oracle Database           NaN          NaN
# 2  PostgreSQL           NaN               NaN     MongoDB           NaN
#
#   Q32_B_Part_7 Q32_B_Part_8 Q32_B_Part_9 Q32_B_Part_10 Q32_B_Part_11  \
# 0          NaN          NaN          NaN           NaN           NaN
# 1          NaN          NaN          NaN           NaN           NaN
# 2          NaN          NaN          NaN           NaN           NaN
#
#   Q32_B_Part_12 Q32_B_Part_13 Q32_B_Part_14 Q32_B_Part_15      Q32_B_Part_16  \
# 0           NaN           NaN           NaN           NaN                NaN
# 1           NaN           NaN           NaN           NaN  Google Cloud SQL
# 2           NaN           NaN           NaN           NaN                NaN
#
#   Q32_B_Part_17 Q32_B_Part_18 Q32_B_Part_19 Q32_B_Part_20 Q32_B_OTHER  \
# 0           NaN           NaN           NaN           NaN         NaN
# 1           NaN           NaN           NaN           NaN         NaN
# 2           NaN           NaN           NaN           NaN         NaN
#
#          Q34_B_Part_1 Q34_B_Part_2        Q34_B_Part_3 Q34_B_Part_4  \
# 0                 NaN          NaN                 NaN          NaN
# 1                 NaN          NaN  Google Data Studio          NaN
# 2  Microsoft Power BI          NaN                 NaN          NaN
#
#   Q34_B_Part_5 Q34_B_Part_6 Q34_B_Part_7 Q34_B_Part_8 Q34_B_Part_9  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN         Qlik          NaN
# 2      Tableau          NaN          NaN          NaN          NaN
#
#   Q34_B_Part_10 Q34_B_Part_11 Q34_B_Part_12 Q34_B_Part_13 Q34_B_Part_14  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
#
#   Q34_B_Part_15 Q34_B_Part_16 Q34_B_OTHER Q36_B_Part_1 Q36_B_Part_2  \
# 0           NaN           NaN         NaN          NaN          NaN
# 1           NaN           NaN         NaN          NaN          NaN
# 2           NaN           NaN         NaN          NaN          NaN
#
#                                         Q36_B_Part_3 Q36_B_Part_4  \
# 0                                                NaN          NaN
# 1  Automated model selection (e.g. auto-sklearn, ...          NaN
# 2  Automated model selection (e.g. auto-sklearn, ...          NaN
#
#   Q36_B_Part_5 Q36_B_Part_6 Q36_B_Part_7 Q36_B_OTHER           Q37_B_Part_1  \
# 0          NaN          NaN          NaN         NaN                    NaN
# 1          NaN          NaN          NaN         NaN   Google Cloud AutoML
# 2          NaN          NaN          NaN         NaN                    NaN
#
#   Q37_B_Part_2 Q37_B_Part_3        Q37_B_Part_4 Q37_B_Part_5 Q37_B_Part_6  \
# 0          NaN          NaN                 NaN          NaN          NaN
# 1          NaN          NaN                 NaN          NaN          NaN
# 2          NaN          NaN   DataRobot AutoML           NaN          NaN
#
#   Q37_B_Part_7 Q37_B_OTHER Q38_B_Part_1 Q38_B_Part_2 Q38_B_Part_3  \
# 0          NaN         NaN          NaN          NaN          NaN
# 1          NaN         NaN          NaN          NaN          NaN
# 2          NaN         NaN          NaN          NaN          NaN
#
#   Q38_B_Part_4   Q38_B_Part_5 Q38_B_Part_6 Q38_B_Part_7 Q38_B_Part_8  \
# 0          NaN            NaN          NaN          NaN          NaN
# 1          NaN            NaN          NaN          NaN          NaN
# 2          NaN   TensorBoard           NaN          NaN          NaN
#
#   Q38_B_Part_9 Q38_B_Part_10 Q38_B_Part_11 Q38_B_OTHER
# 0          NaN           NaN           NaN         NaN
# 1          NaN           NaN          None         NaN
# 2          NaN           NaN           NaN         NaN

# %%
df.age.dtypes
# Out:
# dtype('O')

# %%
df[df["puesto_trabajo"]!= "Student"].stb.freq(["puesto_trabajo"])
# Out:
#                   puesto_trabajo  count    percent  cumulative_count  \
# 0                 Data Scientist   3616  18.863790              3616
# 1              Software Engineer   2449  12.775836              6065
# 2                          Other   2393  12.483698              8458
# 3                   Data Analyst   2301  12.003756             10759
# 4         Currently not employed   1986  10.360478             12745
# 5             Research Scientist   1538   8.023371             14283
# 6      Machine Learning Engineer   1499   7.819918             15782
# 7               Business Analyst    968   5.049820             16750
# 8        Program/Project Manager    849   4.429026             17599
# 9                  Data Engineer    668   3.484793             18267
# 10               Product Manager    319   1.664145             18586
# 11                  Statistician    313   1.632845             18899
# 12         DBA/Database Engineer    171   0.892065             19070
# 13  Developer Relations/Advocacy     99   0.516459             19169
#
#     cumulative_percent
# 0            18.863790
# 1            31.639626
# 2            44.123324
# 3            56.127080
# 4            66.487558
# 5            74.510929
# 6            82.330847
# 7            87.380667
# 8            91.809693
# 9            95.294486
# 10           96.958631
# 11           98.591476
# 12           99.483541
# 13          100.000000

# %%
df.puesto_trabajo.value_counts()
# Out:
# Student                         6804
# Data Scientist                  3616
# Software Engineer               2449
# Other                           2393
# Data Analyst                    2301
# Currently not employed          1986
# Research Scientist              1538
# Machine Learning Engineer       1499
# Business Analyst                 968
# Program/Project Manager          849
# Data Engineer                    668
# Product Manager                  319
# Statistician                     313
# DBA/Database Engineer            171
# Developer Relations/Advocacy      99
# Name: puesto_trabajo, dtype: int64

# %% [markdown]
# ---
#
# ### Unir columnas de partes
#
# ---

# %% [markdown]
# Intentando unir la col 39

# %%
df_copia = df.copy()
df_copia.head(1)
# Out:
#      age gender   pais           estudios puesto_trabajo experiencia  \
# 0  50-54    Man  India  Bachelor’s degree          Other  5-10 years
#
#   lenguaje_recomendado experiencia_ML                  industria  \
# 0               Python     5-10 years  Manufacturing/Fabrication
#
#      tamaño_empresa        salario  \
# 0  50-249 employees  25,000-29,999
#
#                                       herramienta_DA lenguaje_utilizado  \
# 0  Local development environments (RStudio, Jupyt...          Python, R
#
#             IDE                         herramientas_visualizacion  \
# 0   Vim / Emacs   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
#
#                                  Q16  \
# 0  Scikit-learn , TensorFlow ,Caret
#
#                                                  Q17           Q32    Q34  \
# 0  Linear or Logistic Regression, Decision Trees ...   PostgreSQL    None
#
#   Q10_kaggle        Q10_colab Q10_none  Q28 Q39_Part_1 Q39_Part_2 Q39_Part_3  \
# 0        NaN  Colab Notebooks      NaN  NaN        NaN        NaN        NaN
#
#   Q39_Part_4 Q39_Part_5 Q39_Part_6 Q39_Part_7 Q39_Part_8 Q39_Part_9 Q39_OTHER  \
# 0    GitHub         NaN    Kaggle         NaN        NaN        NaN       NaN
#
#   Q40_Part_1 Q40_Part_2            Q40_Part_3 Q40_Part_4 Q40_Part_5  \
# 0   Coursera        edX  Kaggle Learn Courses   DataCamp        NaN
#
#   Q40_Part_6 Q40_Part_7 Q40_Part_8 Q40_Part_9 Q40_Part_10 Q40_Part_11  \
# 0    Udacity      Udemy        NaN        NaN         NaN         NaN
#
#   Q40_OTHER Q27_B_Part_1 Q27_B_Part_2 Q27_B_Part_3 Q27_B_Part_4 Q27_B_Part_5  \
# 0       NaN          NaN          NaN          NaN          NaN          NaN
#
#   Q27_B_Part_6 Q27_B_Part_7 Q27_B_Part_8 Q27_B_Part_9 Q27_B_Part_10  \
# 0          NaN          NaN          NaN          NaN           NaN
#
#   Q27_B_Part_11 Q27_B_OTHER Q29_B_Part_1 Q29_B_Part_2 Q29_B_Part_3  \
# 0           NaN         NaN          NaN          NaN          NaN
#
#   Q29_B_Part_4 Q29_B_OTHER Q31_B_Part_1 Q31_B_Part_2 Q31_B_Part_3  \
# 0          NaN         NaN          NaN          NaN          NaN
#
#   Q31_B_Part_4 Q31_B_Part_5 Q31_B_Part_6 Q31_B_Part_7 Q31_B_Part_8  \
# 0          NaN          NaN          NaN          NaN          NaN
#
#   Q31_B_Part_9 Q31_B_OTHER Q32_B_Part_1 Q32_B_Part_2 Q32_B_Part_3  \
# 0          NaN         NaN          NaN          NaN          NaN
#
#   Q32_B_Part_4 Q32_B_Part_5 Q32_B_Part_6 Q32_B_Part_7 Q32_B_Part_8  \
# 0          NaN          NaN          NaN          NaN          NaN
#
#   Q32_B_Part_9 Q32_B_Part_10 Q32_B_Part_11 Q32_B_Part_12 Q32_B_Part_13  \
# 0          NaN           NaN           NaN           NaN           NaN
#
#   Q32_B_Part_14 Q32_B_Part_15 Q32_B_Part_16 Q32_B_Part_17 Q32_B_Part_18  \
# 0           NaN           NaN           NaN           NaN           NaN
#
#   Q32_B_Part_19 Q32_B_Part_20 Q32_B_OTHER Q34_B_Part_1 Q34_B_Part_2  \
# 0           NaN           NaN         NaN          NaN          NaN
#
#   Q34_B_Part_3 Q34_B_Part_4 Q34_B_Part_5 Q34_B_Part_6 Q34_B_Part_7  \
# 0          NaN          NaN          NaN          NaN          NaN
#
#   Q34_B_Part_8 Q34_B_Part_9 Q34_B_Part_10 Q34_B_Part_11 Q34_B_Part_12  \
# 0          NaN          NaN           NaN           NaN           NaN
#
#   Q34_B_Part_13 Q34_B_Part_14 Q34_B_Part_15 Q34_B_Part_16 Q34_B_OTHER  \
# 0           NaN           NaN           NaN           NaN         NaN
#
#   Q36_B_Part_1 Q36_B_Part_2 Q36_B_Part_3 Q36_B_Part_4 Q36_B_Part_5  \
# 0          NaN          NaN          NaN          NaN          NaN
#
#   Q36_B_Part_6 Q36_B_Part_7 Q36_B_OTHER Q37_B_Part_1 Q37_B_Part_2  \
# 0          NaN          NaN         NaN          NaN          NaN
#
#   Q37_B_Part_3 Q37_B_Part_4 Q37_B_Part_5 Q37_B_Part_6 Q37_B_Part_7  \
# 0          NaN          NaN          NaN          NaN          NaN
#
#   Q37_B_OTHER Q38_B_Part_1 Q38_B_Part_2 Q38_B_Part_3 Q38_B_Part_4  \
# 0         NaN          NaN          NaN          NaN          NaN
#
#   Q38_B_Part_5 Q38_B_Part_6 Q38_B_Part_7 Q38_B_Part_8 Q38_B_Part_9  \
# 0          NaN          NaN          NaN          NaN          NaN
#
#   Q38_B_Part_10 Q38_B_Part_11 Q38_B_OTHER
# 0           NaN           NaN         NaN

# %%
# Pasamos una función para unirlos, borra los nan y los convierte en un string vacío
df_copia['concat_q39'] = df_copia[['Q39_Part_1','Q39_Part_2','Q39_Part_3','Q39_Part_4','Q39_Part_5','Q39_Part_6','Q39_Part_7', 'Q39_Part_8','Q39_Part_9','Q39_OTHER']].apply(lambda x: ','.join(x.dropna().astype(str)), axis=1)
# Reemplazamos los strings vacios por nan
df_copia["concat_q39"].replace("", np.nan, inplace=True)

# %%
df_copia.concat_q39.unique()
# Out:
# array([' GitHub , Kaggle ', nan, 'I do not share my work publicly',
#        ' Plotly Dash , Kaggle ', ' Kaggle ', ' GitHub , Kaggle , Colab ',
#        'Other',
#        ' Plotly Dash , Streamlit , GitHub , Personal blog , Kaggle , Colab ',
#        ' GitHub ', ' Colab ', ' Kaggle , Colab ',
#        ' Streamlit , NBViewer ', ' GitHub , Personal blog ',
#        ' Personal blog ', ' NBViewer , GitHub , Kaggle , Colab ',
#        ' GitHub , Personal blog , Shiny ',
#        ' GitHub , Personal blog , Colab ',
#        ' Plotly Dash , Streamlit , GitHub ', ' GitHub ,Other',
#        ' GitHub , Colab ',
#        ' Plotly Dash , Streamlit , GitHub , Colab , Shiny ',
#        ' NBViewer , GitHub , Colab ', ' Plotly Dash , Streamlit ',
#        ' Streamlit , GitHub , Kaggle , Colab ',
#        ' Streamlit , GitHub , Personal blog ',
#        ' Streamlit , GitHub , Kaggle ', ' Personal blog , Kaggle ',
#        ' Plotly Dash , Streamlit , Shiny ',
#        ' Plotly Dash , Streamlit , GitHub , Kaggle ',
#        ' Plotly Dash , GitHub , Personal blog , Kaggle , Colab ',
#        ' Plotly Dash , GitHub , Shiny ',
#        ' GitHub , Personal blog , Kaggle ',
#        ' GitHub , Personal blog , Kaggle , Colab ',
#        ' Plotly Dash , Streamlit , NBViewer , GitHub , Personal blog , Kaggle , Colab , Shiny ',
#        ' GitHub , Colab , Shiny ', ' Plotly Dash , Colab , Shiny ',
#        ' Plotly Dash , Streamlit , GitHub , Colab ',
#        ' Streamlit , GitHub , Personal blog , Kaggle , Colab , Shiny ',
#        ' Plotly Dash , GitHub , Kaggle ',
#        ' NBViewer , GitHub , Personal blog ', ' Plotly Dash ',
#        ' Streamlit , GitHub , Kaggle , Shiny ', ' Streamlit , Kaggle ',
#        ' Plotly Dash , GitHub , Kaggle , Colab ',
#        ' Plotly Dash , GitHub ', ' Streamlit , GitHub , Colab ',
#        ' Plotly Dash , Streamlit , Kaggle ', ' Shiny ',
#        ' GitHub , Kaggle , Shiny ', ' Streamlit , GitHub ',
#        ' NBViewer , GitHub ', ' GitHub , Kaggle , Colab ,Other',
#        ' GitHub , Personal blog ,Other',
#        ' NBViewer , GitHub , Personal blog , Kaggle , Colab ',
#        ' NBViewer ',
#        ' Plotly Dash , Streamlit , NBViewer , GitHub , Kaggle , Colab , Shiny ',
#        ' Streamlit , NBViewer , GitHub , Personal blog , Kaggle , Colab ',
#        ' Streamlit ', ' Kaggle ,Other',
#        ' Plotly Dash , Streamlit , GitHub , Personal blog , Kaggle , Shiny ',
#        ' Plotly Dash , NBViewer , Kaggle ',
#        ' Plotly Dash , GitHub , Kaggle , Colab , Shiny ',
#        ' Streamlit , Shiny ', ' Plotly Dash , Shiny ',
#        ' GitHub , Kaggle , Colab , Shiny ', ' GitHub , Shiny ',
#        ' Plotly Dash , NBViewer , GitHub , Personal blog , Kaggle , Colab ',
#        ' GitHub , Kaggle ,Other',
#        ' Plotly Dash , Streamlit , NBViewer , GitHub , Kaggle , Colab ',
#        ' Streamlit , GitHub , Shiny ',
#        ' Plotly Dash , GitHub , Personal blog , Kaggle , Colab , Shiny ',
#        ' Plotly Dash , Streamlit , GitHub ,Other',
#        ' NBViewer , GitHub , Personal blog , Colab ',
#        ' Plotly Dash , Streamlit , GitHub , Kaggle , Colab ',
#        ' GitHub , Personal blog , Kaggle , Shiny ',
#        ' NBViewer , GitHub , Personal blog , Kaggle ',
#        ' Personal blog , Kaggle ,Other', ' Plotly Dash , Kaggle , Colab ',
#        ' Plotly Dash , Streamlit , GitHub , Personal blog , Colab ',
#        ' Plotly Dash , GitHub , Personal blog , Colab ',
#        ' Kaggle , Shiny ', ' NBViewer , Colab ',
#        ' Streamlit , GitHub , Kaggle , Colab , Shiny ',
#        ' Streamlit , NBViewer , GitHub , Kaggle ',
#        ' Streamlit , GitHub , Personal blog , Kaggle , Colab ',
#        ' Streamlit , GitHub , Personal blog , Colab ',
#        ' Plotly Dash , NBViewer ', ' Plotly Dash , Personal blog ',
#        ' Plotly Dash , Personal blog , Kaggle ',
#        ' Streamlit , GitHub , Personal blog , Kaggle ',
#        ' Personal blog , Colab ', ' NBViewer , GitHub , Kaggle ',
#        ' Plotly Dash , NBViewer , Personal blog , Shiny ',
#        ' GitHub , Personal blog , Kaggle , Colab , Shiny ',
#        ' Plotly Dash , Colab ',
#        ' Plotly Dash , Streamlit , GitHub , Personal blog , Kaggle , Colab , Shiny ',
#        ' Plotly Dash , GitHub , Colab ',
#        ' Plotly Dash , Streamlit , GitHub , Kaggle , Colab , Shiny ',
#        ' GitHub , Personal blog , Colab , Shiny ',
#        ' Plotly Dash , GitHub , Personal blog , Shiny ',
#        ' Personal blog , Kaggle , Colab ',
#        ' Plotly Dash , Streamlit , NBViewer , GitHub , Personal blog , Kaggle ',
#        ' Streamlit , Colab ', ' GitHub , Personal blog , Kaggle ,Other',
#        ' Streamlit , NBViewer , GitHub , Personal blog , Kaggle ',
#        ' NBViewer , Kaggle ', ' Plotly Dash , Personal blog , Shiny ',
#        ' GitHub , Personal blog , Colab ,Other',
#        ' Plotly Dash , NBViewer , GitHub , Personal blog , Colab , Shiny ',
#        ' Streamlit , GitHub ,Other',
#        ' Plotly Dash , GitHub , Personal blog ',
#        ' Plotly Dash , Streamlit , Kaggle , Colab ',
#        ' NBViewer , GitHub , Personal blog , Kaggle , Colab , Shiny ',
#        ' Streamlit , NBViewer , GitHub , Personal blog , Colab ',
#        ' Personal blog , Shiny ',
#        ' Streamlit , Personal blog , Kaggle , Colab ',
#        ' Streamlit , NBViewer , GitHub , Kaggle , Colab ',
#        ' Plotly Dash , NBViewer , Personal blog , Kaggle , Colab , Shiny ',
#        ' GitHub , Kaggle , Shiny ,Other', ' Streamlit ,Other',
#        ' Streamlit , GitHub , Kaggle , Colab ,Other',
#        ' Streamlit , Personal blog ',
#        ' Plotly Dash , GitHub , Colab , Shiny ',
#        ' Streamlit , NBViewer , GitHub , Personal blog ',
#        ' Plotly Dash , Personal blog ,Other',
#        ' Plotly Dash , NBViewer , GitHub , Kaggle ',
#        ' Plotly Dash , Streamlit , Kaggle , Colab , Shiny ',
#        ' GitHub , Personal blog , Kaggle , Colab ,Other',
#        ' NBViewer , Personal blog , Kaggle ',
#        ' NBViewer , Kaggle , Colab ',
#        ' Plotly Dash , GitHub , Kaggle , Shiny ',
#        ' Streamlit , NBViewer , GitHub ',
#        ' Personal blog , Kaggle , Colab ,Other',
#        ' Plotly Dash , Streamlit , NBViewer , Colab , Shiny ',
#        ' NBViewer , GitHub ,Other',
#        ' Streamlit , Personal blog , Kaggle ',
#        ' Plotly Dash , GitHub , Personal blog , Kaggle ',
#        ' Personal blog , Shiny ,Other',
#        ' Plotly Dash , NBViewer , GitHub , Personal blog ',
#        ' NBViewer , GitHub , Kaggle , Shiny ',
#        ' Plotly Dash , Kaggle , Colab , Shiny ',
#        ' Plotly Dash , NBViewer , GitHub , Colab ', ' Shiny ,Other',
#        ' Colab , Shiny ', ' GitHub , Colab ,Other',
#        ' NBViewer , GitHub , Kaggle , Colab ,Other',
#        ' Plotly Dash , Streamlit , GitHub , Personal blog , Kaggle , Colab , Shiny ,Other',
#        ' Kaggle , Colab ,Other', ' Plotly Dash , NBViewer , GitHub ',
#        ' GitHub , Shiny ,Other', ' Streamlit , Kaggle , Colab ',
#        ' Plotly Dash , Streamlit , Personal blog ',
#        ' Streamlit , GitHub , Colab ,Other',
#        ' Streamlit , NBViewer , Colab , Shiny ', ' Personal blog ,Other',
#        ' Streamlit , GitHub , Personal blog , Shiny ',
#        ' Plotly Dash , NBViewer , Personal blog ',
#        ' Kaggle , Colab , Shiny ',
#        ' Plotly Dash , NBViewer , GitHub , Personal blog , Kaggle , Shiny ',
#        ' Plotly Dash , Personal blog , Colab ',
#        ' Streamlit , GitHub , Personal blog , Kaggle , Shiny ',
#        ' NBViewer , GitHub , Personal blog , Kaggle , Shiny ',
#        ' NBViewer , Kaggle , Shiny ', ' NBViewer ,Other',
#        ' Streamlit , GitHub , Personal blog , Colab , Shiny ',
#        ' GitHub , Colab , Shiny ,Other', ' Colab ,Other',
#        ' Plotly Dash , NBViewer , Personal blog , Kaggle ',
#        ' Plotly Dash , Streamlit , NBViewer , GitHub , Kaggle ',
#        ' Plotly Dash , Streamlit , GitHub , Personal blog ',
#        ' Streamlit , NBViewer , Personal blog , Kaggle , Colab '],
#       dtype=object)

# %%
#Definimos la función para que se unan las columnas restantes
def concat(df,col_ini, col_fin,nombre):
    columnas = df.loc[:,col_ini:col_fin].columns
    df[nombre] = df[columnas].apply(lambda x: ','.join(x.dropna().astype(str)), axis=1)
    df[nombre].replace("", np.nan, inplace=True)
    df.drop(columnas, axis = 1, inplace = True) #Eliminas las columnas concatenadas

# %%
#Aplicamos a Q39
concat(df,'Q39_Part_1','Q39_OTHER','q39_plat_compartir_trabajo')

# %%
#Aplicamos a Q40
concat(df,'Q40_Part_1','Q40_OTHER','q40_plat_cursos')

# %%
#Aplicamos a Q27_B
concat(df,'Q27_B_Part_1','Q27_B_OTHER','q27_plat_familiar_cloud_computing')

# %%
#Aplicamos a Q29_B
concat(df,'Q29_B_Part_1','Q29_B_OTHER','q29b_productos_familiar_cloud_computing')

# %%
#Aplicamos a Q31_B
concat(df,'Q31_B_Part_1','Q31_B_OTHER','q31b_productos_familiar_ml')

# %%
#Aplicamos a Q32_B
concat(df,'Q32_B_Part_1','Q32_B_OTHER','q32b_productos_familiar_bd')

# %%
#Aplicamos a Q34_B
concat(df,'Q34_B_Part_1','Q34_B_OTHER','q34b_herramientas_familiar_bi')

# %%
#Aplicamos a Q36_B
concat(df,'Q36_B_Part_1','Q36_B_OTHER','q36b_cat_herramientas_familiar_ml')

# %%
#Aplicamos a Q37_B
concat(df,'Q37_B_Part_1','Q37_B_OTHER','q37b_cat_herramientas_familiar_ml_aut')

# %%
#Aplicamos a Q38_B
concat(df,'Q38_B_Part_1','Q38_B_OTHER','q38b_herramientas_familiar_gest_exp_ml')

# %%
df.head()
# Out:
#      age gender       pais           estudios           puesto_trabajo  \
# 0  50-54    Man      India  Bachelor’s degree                    Other
# 1  50-54    Man  Indonesia    Master’s degree  Program/Project Manager
# 2  22-24    Man   Pakistan    Master’s degree        Software Engineer
# 3  45-49    Man     Mexico    Doctoral degree       Research Scientist
# 4  45-49    Man      India    Doctoral degree                    Other
#
#   experiencia lenguaje_recomendado                         experiencia_ML  \
# 0  5-10 years               Python                             5-10 years
# 1   20+ years               Python                               < 1 year
# 2   1-3 years               Python  I do not use machine learning methods
# 3   20+ years               Python                             5-10 years
# 4   < 1 years               Python                            10-20 years
#
#                    industria        tamaño_empresa        salario  \
# 0  Manufacturing/Fabrication      50-249 employees  25,000-29,999
# 1  Manufacturing/Fabrication  1000-9,999 employees  60,000-69,999
# 2        Academics/Education  1000-9,999 employees         $0-999
# 3        Academics/Education  1000-9,999 employees  30,000-39,999
# 4        Academics/Education      50-249 employees  30,000-39,999
#
#                                       herramienta_DA  lenguaje_utilizado  \
# 0  Local development environments (RStudio, Jupyt...           Python, R
# 1    Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
# 2  Basic statistical software (Microsoft Excel, G...   Python, C++, Java
# 3  Local development environments (RStudio, Jupyt...              Python
# 4  Local development environments (RStudio, Jupyt...   Python, C, MATLAB
#
#                                 IDE  \
# 0                       Vim / Emacs
# 1        Notepad++,Jupyter Notebook
# 2  PyCharm ,Jupyter Notebook, Other
# 3           Spyder,Jupyter Notebook
# 4   Spyder,MATLAB ,Jupyter Notebook
#
#                           herramientas_visualizacion  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
# 1                                        Matplotlib
# 2                                        Matplotlib
# 3                                        Matplotlib
# 4             Matplotlib ,Seaborn ,Ggplot / ggplot2
#
#                                  Q16  \
# 0  Scikit-learn , TensorFlow ,Caret
# 1                      Scikit-learn
# 2                                NaN
# 3  Scikit-learn , TensorFlow ,Keras
# 4   Scikit-learn ,PyTorch ,LightGBM
#
#                                                  Q17               Q32  \
# 0  Linear or Logistic Regression, Decision Trees ...       PostgreSQL
# 1  Linear or Logistic Regression, Decision Trees ...               NaN
# 2                                                NaN  MySQL , MongoDB
# 3   Dense Neural Networks (MLPs, etc), Convolutio...               NaN
# 4  Linear or Logistic Regression, Decision Trees ...              None
#
#                    Q34         Q10_kaggle        Q10_colab Q10_none  Q28  \
# 0                 None                NaN  Colab Notebooks      NaN  NaN
# 1                  NaN   Kaggle Notebooks  Colab Notebooks      NaN  NaN
# 2                 None   Kaggle Notebooks              NaN      NaN  NaN
# 3                  NaN                NaN  Colab Notebooks      NaN  NaN
# 4   Microsoft Power BI                NaN              NaN      NaN  NaN
#
#         q39_plat_compartir_trabajo  \
# 0                 GitHub , Kaggle
# 1                              NaN
# 2  I do not share my work publicly
# 3                              NaN
# 4  I do not share my work publicly
#
#                                      q40_plat_cursos  \
# 0  Coursera,edX,Kaggle Learn Courses,DataCamp,Uda...
# 1  Kaggle Learn Courses,Cloud-certification progr...
# 2                                           DataCamp
# 3                                       Coursera,edX
# 4                         Kaggle Learn Courses,Udemy
#
#                    q27_plat_familiar_cloud_computing  \
# 0                                                NaN
# 1        Google Cloud Platform (GCP) , Oracle Cloud
# 2   Amazon Web Services (AWS) , Google Cloud Plat...
# 3       Amazon Web Services (AWS) , Microsoft Azure
# 4                                                NaN
#
#              q29b_productos_familiar_cloud_computing  \
# 0                                                NaN
# 1                       Google Cloud Compute Engine
# 2   Microsoft Azure Virtual Machines , Google Clo...
# 3   Microsoft Azure Virtual Machines , Google Clo...
# 4                                                NaN
#
#                           q31b_productos_familiar_ml  \
# 0                                                NaN
# 1                                               None
# 2   Azure Machine Learning Studio , Google Cloud ...
# 3                                               None
# 4                                                NaN
#
#                           q32b_productos_familiar_bd  \
# 0                                                NaN
# 1  MySQL ,SQLite ,Oracle Database ,Google Cloud SQL
# 2                        MySQL ,PostgreSQL ,MongoDB
# 3                                               None
# 4                                                NaN
#
#   q34b_herramientas_familiar_bi  \
# 0                           NaN
# 1       Google Data Studio,Qlik
# 2    Microsoft Power BI,Tableau
# 3                          None
# 4                           NaN
#
#                    q36b_cat_herramientas_familiar_ml  \
# 0                                                NaN
# 1  Automated model selection (e.g. auto-sklearn, ...
# 2  Automated model selection (e.g. auto-sklearn, ...
# 3                                               None
# 4                                                NaN
#
#   q37b_cat_herramientas_familiar_ml_aut q38b_herramientas_familiar_gest_exp_ml
# 0                                   NaN                                    NaN
# 1                  Google Cloud AutoML                                    None
# 2                     DataRobot AutoML                            TensorBoard
# 3                                   NaN                                   None
# 4                                   NaN                                    NaN

# %% [markdown]
# ## Columna salario

# %%
df["salario"].unique()
# Out:
# array(['25,000-29,999', '60,000-69,999', '$0-999', '30,000-39,999', nan,
#        '15,000-19,999', '70,000-79,999', '2,000-2,999', '10,000-14,999',
#        '5,000-7,499', '20,000-24,999', '1,000-1,999', '100,000-124,999',
#        '7,500-9,999', '4,000-4,999', '40,000-49,999', '50,000-59,999',
#        '3,000-3,999', '300,000-499,999', '200,000-249,999',
#        '125,000-149,999', '250,000-299,999', '80,000-89,999',
#        '90,000-99,999', '150,000-199,999', '>$1,000,000',
#        '$500,000-999,999'], dtype=object)

# %%
def limpiar(x):
    try:
        return x.split("-")[1].replace(",","")
    except:
        return x

# %%
def quitar_dolar(x):
    try:
        return x.replace(">$","").replace(",","")
    except:
        return x

# %%
df["salario"] = df["salario"].apply(limpiar).apply(quitar_dolar).astype("Int64", errors= "raise")

# %%
df["salario"].unique()
# Out:
# <IntegerArray>
# [  29999,   69999,     999,   39999,    <NA>,   19999,   79999,    2999,
#    14999,    7499,   24999,    1999,  124999,    9999,    4999,   49999,
#    59999,    3999,  499999,  249999,  149999,  299999,   89999,   99999,
#   199999, 1000000,  999999]
# Length: 27, dtype: Int64

# %%
sns.boxplot(x= "salario", data=df[(df["puesto_trabajo"]!= "Student")]);

# %%
df["salario"].dtype
# Out:
# Int64Dtype()

# %% [markdown]
# ### Renombrar últimas columnas

# %%
q_restantes = {'Q16':'Q16_frame_ml','Q17':'Q17_alg_ml','Q32':'Q32_prod_bigdata','Q34':'Q34_herramientas_bi'}

# %%
df.rename(columns = q_restantes, inplace =True)
df.head(2)
# Out:
#      age gender       pais           estudios           puesto_trabajo  \
# 0  50-54    Man      India  Bachelor’s degree                    Other
# 1  50-54    Man  Indonesia    Master’s degree  Program/Project Manager
#
#   experiencia lenguaje_recomendado experiencia_ML                  industria  \
# 0  5-10 years               Python     5-10 years  Manufacturing/Fabrication
# 1   20+ years               Python       < 1 year  Manufacturing/Fabrication
#
#          tamaño_empresa  salario  \
# 0      50-249 employees    29999
# 1  1000-9,999 employees    69999
#
#                                       herramienta_DA  lenguaje_utilizado  \
# 0  Local development environments (RStudio, Jupyt...           Python, R
# 1    Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
#
#                            IDE  \
# 0                  Vim / Emacs
# 1   Notepad++,Jupyter Notebook
#
#                           herramientas_visualizacion  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
# 1                                        Matplotlib
#
#                         Q16_frame_ml  \
# 0  Scikit-learn , TensorFlow ,Caret
# 1                      Scikit-learn
#
#                                           Q17_alg_ml Q32_prod_bigdata  \
# 0  Linear or Logistic Regression, Decision Trees ...      PostgreSQL
# 1  Linear or Logistic Regression, Decision Trees ...              NaN
#
#   Q34_herramientas_bi         Q10_kaggle        Q10_colab Q10_none  Q28  \
# 0                None                NaN  Colab Notebooks      NaN  NaN
# 1                 NaN   Kaggle Notebooks  Colab Notebooks      NaN  NaN
#
#   q39_plat_compartir_trabajo  \
# 0           GitHub , Kaggle
# 1                        NaN
#
#                                      q40_plat_cursos  \
# 0  Coursera,edX,Kaggle Learn Courses,DataCamp,Uda...
# 1  Kaggle Learn Courses,Cloud-certification progr...
#
#               q27_plat_familiar_cloud_computing  \
# 0                                           NaN
# 1   Google Cloud Platform (GCP) , Oracle Cloud
#
#   q29b_productos_familiar_cloud_computing q31b_productos_familiar_ml  \
# 0                                     NaN                        NaN
# 1            Google Cloud Compute Engine                        None
#
#                           q32b_productos_familiar_bd  \
# 0                                                NaN
# 1  MySQL ,SQLite ,Oracle Database ,Google Cloud SQL
#
#   q34b_herramientas_familiar_bi  \
# 0                           NaN
# 1       Google Data Studio,Qlik
#
#                    q36b_cat_herramientas_familiar_ml  \
# 0                                                NaN
# 1  Automated model selection (e.g. auto-sklearn, ...
#
#   q37b_cat_herramientas_familiar_ml_aut q38b_herramientas_familiar_gest_exp_ml
# 0                                   NaN                                    NaN
# 1                  Google Cloud AutoML                                    None

# %%
#Guardamos un nuevo csv con todos los cambios realizados
df.to_csv("../Archivos/archivo_limpio_pruebas.csv", index = False)

# %% [markdown]
# ## Separar las columnas concatenadas en otros df para la visualizacion

# %%
# Hacemos un nuevo DF solo con las columnas, edad, genero, puesto de trabajo y concat_q39
df_q39 = df_copia[["age", "gender", "puesto_trabajo", "concat_q39"]]

# %%
# Hacemos un split para convertirlo en lista
df_q39.loc[:,"concat_q39"] = df_q39['concat_q39'].str.split(",")
# Out:
# /tmp/ipykernel_1749/4023251198.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_q39.loc[:,"concat_q39"] = df_q39['concat_q39'].str.split(",")
