# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_columns=None

# %% [markdown]
# ## Archivo data_remaning_kaggle.csv
# ---

# %%
kaggle = pd.read_csv('data_remaning_kaggle.csv')
kaggle.head(3)
# Out:
#    Unnamed: 0  index                                         Q18_Part_1  \
# 0           0      0  General purpose image/video tools (PIL, cv2, s...
# 1           1      1                                                NaN
# 2           2      2                                                NaN
#
#   Q18_Part_2 Q18_Part_3 Q18_Part_4 Q18_Part_5 Q18_Part_6 Q18_OTHER  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN
# 1        NaN        NaN        NaN        NaN        NaN       NaN
# 2        NaN        NaN        NaN        NaN        NaN       NaN
#
#                                           Q19_Part_1 Q19_Part_2 Q19_Part_3  \
# 0  Word embeddings/vectors (GLoVe, fastText, word...        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                                                NaN        NaN        NaN
#
#   Q19_Part_4 Q19_Part_5 Q19_OTHER Q27_A_Part_1 Q27_A_Part_2  \
# ...

# %%
list(kaggle.columns)
# Out:
# ['Unnamed: 0',
#  'index',
#  'Q18_Part_1',
#  'Q18_Part_2',
#  'Q18_Part_3',
#  'Q18_Part_4',
#  'Q18_Part_5',
#  'Q18_Part_6',
#  'Q18_OTHER',
#  'Q19_Part_1',
#  'Q19_Part_2',
#  'Q19_Part_3',
#  'Q19_Part_4',
#  'Q19_Part_5',
#  'Q19_OTHER',
#  'Q27_A_Part_1',
#  'Q27_A_Part_2',
#  'Q27_A_Part_3',
#  'Q27_A_Part_4',
#  'Q27_A_Part_5',
#  'Q27_A_Part_6',
#  'Q27_A_Part_7',
#  'Q27_A_Part_8',
#  'Q27_A_Part_9',
#  'Q27_A_Part_10',
#  'Q27_A_Part_11',
#  'Q27_A_OTHER',
#  'Q28',
#  'Q29_A_Part_1',
#  'Q29_A_Part_2',
#  'Q29_A_Part_3',
#  'Q29_A_Part_4',
#  'Q29_A_OTHER',
#  'Q30_A_Part_1',
#  'Q30_A_Part_2',
#  'Q30_A_Part_3',
#  'Q30_A_Part_4',
#  'Q30_A_Part_5',
#  'Q30_A_Part_6',
#  'Q30_A_Part_7',
#  'Q30_A_OTHER',
#  'Q31_A_Part_1',
#  'Q31_A_Part_2',
#  'Q31_A_Part_3',
#  'Q31_A_Part_4',
#  'Q31_A_Part_5',
#  'Q31_A_Part_6',
#  'Q31_A_Part_7',
#  'Q31_A_Part_8',
#  'Q31_A_Part_9',
#  'Q31_A_OTHER',
#  'Q36_A_Part_1',
#  'Q36_A_Part_2',
#  'Q36_A_Part_3',
#  'Q36_A_Part_4',
# ...

# %%
kaggle.shape
# Out:
# (25973, 214)

# %%
kaggle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25973 entries, 0 to 25972
# Columns: 214 entries, Unnamed: 0 to Q38_B_OTHER
# dtypes: float64(8), int64(2), object(204)
# memory usage: 42.4+ MB

# %%
kaggle.describe().T
# Out:
#                 count     mean          std  min     25%      50%      75%  \
# Unnamed: 0    25973.0  12986.0  7497.903607  0.0  6493.0  12986.0  19479.0
# index         25973.0  12986.0  7497.903607  0.0  6493.0  12986.0  19479.0
# Q30_B_Part_1      0.0      NaN          NaN  NaN     NaN      NaN      NaN
# Q30_B_Part_2      0.0      NaN          NaN  NaN     NaN      NaN      NaN
# Q30_B_Part_3      0.0      NaN          NaN  NaN     NaN      NaN      NaN
# Q30_B_Part_4      0.0      NaN          NaN  NaN     NaN      NaN      NaN
# Q30_B_Part_5      0.0      NaN          NaN  NaN     NaN      NaN      NaN
# Q30_B_Part_6      0.0      NaN          NaN  NaN     NaN      NaN      NaN
# Q30_B_Part_7      0.0      NaN          NaN  NaN     NaN      NaN      NaN
# Q30_B_OTHER       0.0      NaN          NaN  NaN     NaN      NaN      NaN
#
#                   max
# Unnamed: 0    25972.0
# index         25972.0
# Q30_B_Part_1      NaN
# Q30_B_Part_2      NaN
# Q30_B_Part_3      NaN
# ...

# %%
kaggle.describe(include = 'object').T
# Out:
#               count unique                                                top  \
# Q18_Part_1     2662      1  General purpose image/video tools (PIL, cv2, s...
# Q18_Part_2     2740      1  Image segmentation methods (U-Net, Mask R-CNN,...
# Q18_Part_3     2716      1  Object detection methods (YOLOv3, RetinaNet, etc)
# Q18_Part_4     4373      1  Image classification and other general purpose...
# Q18_Part_5     1492      1                Generative Networks (GAN, VAE, etc)
# ...             ...    ...                                                ...
# Q38_B_Part_8   1020      1                                           ClearML
# Q38_B_Part_9    666      1                              Domino Model Monitor
# Q38_B_Part_10  2747      1                                            MLflow
# Q38_B_Part_11  4542      1                                               None
# Q38_B_OTHER     377      1                                              Other
#
#                freq
# ...

# %%
kaggle.duplicated().sum()
# Out:
# 0

# %%
#kaggle.duplicated(subset = ['']).sum()  # por revisar

# %%
kaggle.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
kaggle.isnull().sum()/len(kaggle)*100
# Out:
# index             0.000000
# Q18_Part_1       89.750895
# Q18_Part_2       89.450583
# Q18_Part_3       89.542987
# Q18_Part_4       83.163285
#                    ...
# Q38_B_Part_8     96.072845
# Q38_B_Part_9     97.435799
# Q38_B_Part_10    89.423632
# Q38_B_Part_11    82.512609
# Q38_B_OTHER      98.548493
# Length: 213, dtype: float64

# %%
kaggle.size
# Out:
# 5532249

# %% [markdown]
# ## Archivo exported_db_data.csv
# ---

# %%
respuesta_q10= pd.read_csv('exported_db_data.csv')
respuesta_q10.head(10)
# Out:
#    index         Q10_Part_1       Q10_Part_2 Q10_Part_3 Q10_Part_4 Q10_Part_5  \
# 0      0                NaN  Colab Notebooks        NaN        NaN        NaN
# 1      1   Kaggle Notebooks  Colab Notebooks        NaN        NaN        NaN
# 2      2   Kaggle Notebooks              NaN        NaN        NaN        NaN
# 3      3                NaN  Colab Notebooks        NaN        NaN        NaN
# 4      4                NaN              NaN        NaN        NaN        NaN
# 5      5                NaN  Colab Notebooks        NaN        NaN        NaN
# 6      6   Kaggle Notebooks              NaN        NaN        NaN        NaN
# 7      7   Kaggle Notebooks              NaN        NaN        NaN        NaN
# 8      8   Kaggle Notebooks  Colab Notebooks        NaN        NaN        NaN
# 9      9   Kaggle Notebooks              NaN        NaN        NaN        NaN
#
#   Q10_Part_6 Q10_Part_7 Q10_Part_8 Q10_Part_9  \
# 0        NaN        NaN        NaN        NaN
# ...

# %% [markdown]
# Vemos el porcentaje de nulls

# %%
respuesta_q10.isnull().sum()/len(respuesta_q10)*100
# Out:
# index           0.000000
# Q10_Part_1     63.396604
# Q10_Part_2     62.299311
# Q10_Part_3     95.911138
# Q10_Part_4     99.195318
# Q10_Part_5     93.185231
# Q10_Part_6     99.326223
# Q10_Part_7     95.891888
# Q10_Part_8     97.100835
# Q10_Part_9     98.660147
# Q10_Part_10    92.103338
# Q10_Part_11    93.092827
# Q10_Part_12    97.728410
# Q10_Part_13    99.033612
# Q10_Part_14    98.998960
# Q10_Part_15    99.434028
# Q10_Part_16    72.379009
# Q10_OTHER      97.162438
# dtype: float64

# %% [markdown]
# Del archivo respuesta_q10 lo que más nos interesa son las columnas q10_part1, q10_part2 y q10_part16

# %%
notebooks = respuesta_q10.loc[:,['index','Q10_Part_1','Q10_Part_2','Q10_Part_16']]
notebooks
# Out:
#        index         Q10_Part_1       Q10_Part_2 Q10_Part_16
# 0          0                NaN  Colab Notebooks         NaN
# 1          1   Kaggle Notebooks  Colab Notebooks         NaN
# 2          2   Kaggle Notebooks              NaN         NaN
# 3          3                NaN  Colab Notebooks         NaN
# 4          4                NaN              NaN         NaN
# ...      ...                ...              ...         ...
# 25968  25968                NaN  Colab Notebooks         NaN
# 25969  25969                NaN              NaN        None
# 25970  25970                NaN              NaN         NaN
# 25971  25971                NaN              NaN        None
# 25972  25972                NaN              NaN         NaN
#
# [25973 rows x 4 columns]

# %% [markdown]
# 'notebooks' es ahora el DataFrame del archivo exported_db_data.csv, con las columnas que nos interesan

# %%
columnas_nuevas1 ={'Q10_Part_1':'kaggle','Q10_Part_2':'colab','Q10_Part_16':'ninguno'}

# %%
notebooks.rename(columns = columnas_nuevas1,inplace = True)

# %%
notebooks
# Out:
#        index             kaggle            colab ninguno
# 0          0                NaN  Colab Notebooks     NaN
# 1          1   Kaggle Notebooks  Colab Notebooks     NaN
# 2          2   Kaggle Notebooks              NaN     NaN
# 3          3                NaN  Colab Notebooks     NaN
# 4          4                NaN              NaN     NaN
# ...      ...                ...              ...     ...
# 25968  25968                NaN  Colab Notebooks     NaN
# 25969  25969                NaN              NaN    None
# 25970  25970                NaN              NaN     NaN
# 25971  25971                NaN              NaN    None
# 25972  25972                NaN              NaN     NaN
#
# [25973 rows x 4 columns]

# %% [markdown]
# ## Archivo data_xml_clean.xml
# ---

# %%
data_xml = pd.read_xml('data_xml_clean.xml')
data_xml.head(10)
# Out:
#    level_0  index  time    age gender
# 0        0      0   910  50-54    Man
# 1        1      1   784  50-54    Man
# 2        2      2   924  22-24    Man
# 3        3      3   575  45-49    Man
# 4        4      4   781  45-49    Man
# 5        5      5  1020  25-29  Woman
# 6        6      6   141  18-21  Woman
# 7        7      7   484  30-34    Man
# 8        8      8  1744  22-24    Man
# 9        9      9   655  30-34    Man

# %%
data_xml.drop(['level_0'], axis = 1, inplace = True)

# %%
data_xml
# Out:
#        index  time    age gender
# 0          0   910  50-54    Man
# 1          1   784  50-54    Man
# 2          2   924  22-24    Man
# 3          3   575  45-49    Man
# 4          4   781  45-49    Man
# ...      ...   ...    ...    ...
# 25968  25968  1756  30-34    Man
# 25969  25969   253  22-24    Man
# 25970  25970   494  50-54    Man
# 25971  25971   277  45-49    Man
# 25972  25972   255  18-21    Man
#
# [25973 rows x 4 columns]

# %% [markdown]
# ## Archivo data_txt_clean.txt
# ---

# %%
data_txt = pd.read_csv('data_txt_clean.txt', sep =';')
data_txt.head(2)
# Out:
#    index         Q3                 Q4                       Q5          Q6  \
# 0      0      India  Bachelor’s degree                    Other  5-10 years
# 1      1  Indonesia    Master’s degree  Program/Project Manager   20+ years
#
#        Q8                                                Q11        Q13  \
# 0  Python                                           A laptop  2-5 times
# 1  Python  A cloud computing platform (AWS, Azure, GCP, h...      Never
#
#           Q15                        Q20                   Q21  Q22  \
# 0  5-10 years  Manufacturing/Fabrication      50-249 employees  3-4
# 1    < 1 year  Manufacturing/Fabrication  1000-9,999 employees  1-2
#
#                                                  Q23            Q25  \
# 0                      No (we do not use ML methods)  25,000-29,999
# 1  We are exploring ML methods (and may one day p...  60,000-69,999
#
#          Q26  Q33  Q35                                                Q41  \
# ...

# %%
data_txt.isnull().sum()/len(data_txt)*100 # porcentaje de nulos
# Out:
# index     0.000000
# Q3        0.000000
# Q4        0.000000
# Q5        0.000000
# Q6        0.000000
# Q8        3.977207
# Q11       4.824241
# Q13       6.044739
# Q15       8.543487
# Q20      37.146267
# Q21      37.431179
# Q22      37.912448
# Q23      38.582374
# Q25      40.742309
# Q26      41.543141
# Q33      82.073692
# Q35      91.387210
# Q41      28.814538
# Q7        3.973357
# Q9        4.000308
# Q12       5.355562
# Q14       7.711855
# Q16      24.444616
# Q17      25.634313
# Q24      39.802872
# Q32      63.485158
# Q34      63.812421
# dtype: float64

# %%
# variable para renombrar las columnas 
columnas_nuevas ={'Q3':'pais','Q4':'estudios','Q5':'puesto_trabajos','Q6':'experiencia','Q7':'lenguaje_utilizado','Q8':'lenguaje_recomendado','Q9':'IDE','Q11':'dispositivo','Q12':'hardware','Q14':'herramientas_visualizacion','Q15':'experiencia_ML','Q20':'industria','Q21':'tamaño_empresa','Q22':'responsables_DS','Q24':'tareas_principales','Q25':'salario','Q41':'herramienta_DA'}

# %%
data_txt.rename(columns = columnas_nuevas,inplace = True) # renombrara las columnas
data_txt.head(2)
# Out:
#    index       pais           estudios          puesto_trabajos experiencia  \
# 0      0      India  Bachelor’s degree                    Other  5-10 years
# 1      1  Indonesia    Master’s degree  Program/Project Manager   20+ years
#
#   lenguaje_recomendado                                        dispositivo  \
# 0               Python                                           A laptop
# 1               Python  A cloud computing platform (AWS, Azure, GCP, h...
#
#          Q13 experiencia_ML                  industria        tamaño_empresa  \
# 0  2-5 times     5-10 years  Manufacturing/Fabrication      50-249 employees
# 1      Never       < 1 year  Manufacturing/Fabrication  1000-9,999 employees
#
#   responsables_DS                                                Q23  \
# 0             3-4                      No (we do not use ML methods)
# 1             1-2  We are exploring ML methods (and may one day p...
#
#          salario        Q26  \
# 0  25,000-29,999  $100-$999
# ...

# %%
data_txt.drop(['Q33','Q35'], axis = 1, inplace = True) # borramos las columnas Q33 y Q35

# %%
data_txt.columns # vemos las columnas que tenemo
# Out:
# Index(['index', 'pais', 'estudios', 'puesto_trabajos', 'experiencia',
#        'lenguaje_recomendado', 'dispositivo', 'Q13', 'experiencia_ML',
#        'industria', 'tamaño_empresa', 'responsables_DS', 'Q23', 'salario',
#        'Q26', 'herramienta_DA', 'lenguaje_utilizado', 'IDE', 'hardware',
#        'herramientas_visualizacion', 'Q16', 'Q17', 'tareas_principales', 'Q32',
#        'Q34'],
#       dtype='object')

# %%
data_txt.head(3)
# Out:
#    index       pais           estudios          puesto_trabajos experiencia  \
# 0      0      India  Bachelor’s degree                    Other  5-10 years
# 1      1  Indonesia    Master’s degree  Program/Project Manager   20+ years
# 2      2   Pakistan    Master’s degree        Software Engineer   1-3 years
#
#   lenguaje_recomendado                                        dispositivo  \
# 0               Python                                           A laptop
# 1               Python  A cloud computing platform (AWS, Azure, GCP, h...
# 2               Python                                           A laptop
#
#          Q13                         experiencia_ML  \
# 0  2-5 times                             5-10 years
# 1      Never                               < 1 year
# 2      Never  I do not use machine learning methods
#
#                    industria        tamaño_empresa responsables_DS  \
# 0  Manufacturing/Fabrication      50-249 employees             3-4
# ...

# %%
data_txt['puesto_trabajos'].value_counts()
# Out:
# Student                         6804
# Data Scientist                  3616
# Software Engineer               2449
# Other                           2393
# Data Analyst                    2301
# Currently not employed          1986
# Research Scientist              1538
# Machine Learning Engineer       1499
# Business Analyst                 968
# Program/Project Manager          849
# Data Engineer                    668
# Product Manager                  319
# Statistician                     313
# DBA/Database Engineer            171
# Developer Relations/Advocacy      99
# Name: puesto_trabajos, dtype: int64

# %%
data_txt['experiencia'].value_counts()
# Out:
# 1-3 years                    7874
# < 1 years                    5881
# 3-5 years                    4061
# 5-10 years                   3099
# 10-20 years                  2166
# 20+ years                    1860
# I have never written code    1032
# Name: experiencia, dtype: int64

# %%
data_txt['pais'].value_counts()
# Out:
# India                       7434
# United States of America    2650
# Other                       1270
# Japan                        921
# China                        814
#                             ...
# Kazakhstan                    45
# Norway                        45
# Algeria                       44
# Ethiopia                      43
# Iraq                          43
# Name: pais, Length: 66, dtype: int64

# %% [markdown]
# En las siguientes celdas cambiamos y separamos toda la columna herramientas_visualización hasta convertirlo en un csv para utilizar más tarde

# %%
df_herramientas = data_txt['herramientas_visualizacion'].str.split(',',expand=True)

# %%
df_herramientas
# Out:
#                  0         1                  2       3                  4   \
# 0       Matplotlib   Seaborn   Ggplot / ggplot2   Shiny   Leaflet / Folium
# 1       Matplotlib       None               None    None               None
# 2       Matplotlib       None               None    None               None
# 3       Matplotlib       None               None    None               None
# 4       Matplotlib   Seaborn   Ggplot / ggplot2     None               None
# ...             ...       ...                ...     ...                ...
# 25968   Matplotlib   Seaborn                None    None               None
# 25969          None      None               None    None               None
# 25970           NaN       NaN                NaN     NaN                NaN
# 25971   Matplotlib   Seaborn                None    None               None
# 25972           NaN       NaN                NaN     NaN                NaN
#
#          5     6     7     8     9     10
# ...

# %%
columnas_nuevas2 = {0: 'Matplotlib', 1:'Seaborn', 2: 'Plotly / Plotly Express', 3: 'Ggplot / ggplot2', 4:'Shiny', 5:'D3 js', 6: 'Altair', 7: 'Bokeh', 8: 'Geoplotlib', 9: 'Leaflet / Folium', 10: 'Other'}

# %%
df_herramientas.rename(columns = columnas_nuevas2, inplace = True) # renombrara las columnas
df_herramientas.head(2)
# Out:
#      Matplotlib   Seaborn Plotly / Plotly Express Ggplot / ggplot2  \
# 0   Matplotlib   Seaborn        Ggplot / ggplot2            Shiny
# 1   Matplotlib       None                    None             None
#
#                Shiny D3 js Altair Bokeh Geoplotlib Leaflet / Folium Other
# 0  Leaflet / Folium   None   None  None       None             None  None
# 1               None  None   None  None       None             None  None

# %%
df_herramientas.value_counts()
# Out:
# Matplotlib    Seaborn   Plotly / Plotly Express   Ggplot / ggplot2   Shiny   D3 js   Altair   Bokeh   Geoplotlib   Leaflet / Folium   Other
#  Matplotlib   Seaborn   Plotly / Plotly Express   Ggplot / ggplot2   Shiny   D3 js   Altair   Bokeh   Geoplotlib   Leaflet / Folium    Other    2
# dtype: int64

# %%
df_sum_herramientas= pd.DataFrame(df_herramientas.notnull().sum())
df_sum_herramientas
# Out:
#                              0
# Matplotlib               23970
# Seaborn                  14906
# Plotly / Plotly Express   7301
# Ggplot / ggplot2          2882
# Shiny                     1094
# D3 js                      403
# Altair                     146
# Bokeh                       65
# Geoplotlib                  39
# Leaflet / Folium            29
# Other                        2

# %%
df_sum_herramientas.rename(columns = {0:'sum'}, inplace= True)
df_sum_herramientas
# Out:
#                            sum
# Matplotlib               23970
# Seaborn                  14906
# Plotly / Plotly Express   7301
# Ggplot / ggplot2          2882
# Shiny                     1094
# D3 js                      403
# Altair                     146
# Bokeh                       65
# Geoplotlib                  39
# Leaflet / Folium            29
# Other                        2

# %%
df_sum_herramientas.to_csv('df_sum_herramientas.csv')
