# %%
import pandas as pd

# %%
pd.options.display.max_columns = None

# %%
df_xml = pd.read_csv("../Archivos/xml_limpio.csv", index_col="index")
df_txt = pd.read_csv("../Archivos/txt_limpio.csv", index_col="index")
df_noprof = pd.read_csv("../Archivos/noprof.csv")
df_notebooks = pd.read_csv("../Archivos/notebooks.csv", index_col="index")
df_platform = pd.read_csv("../Archivos/platform.csv")

# %%
df_noprof.head()
# Out:
#    Unnamed: 0                 Q27_B_Part_1       Q27_B_Part_2  \
# 0           0                          NaN                NaN
# 1           1                          NaN                NaN
# 2           2   Amazon Web Services (AWS)                 NaN
# 3           3   Amazon Web Services (AWS)    Microsoft Azure
# 4           4                          NaN                NaN
#
#                     Q27_B_Part_3 Q27_B_Part_4    Q27_B_Part_5 Q27_B_Part_6  \
# 0                            NaN          NaN             NaN          NaN
# 1   Google Cloud Platform (GCP)           NaN   Oracle Cloud           NaN
# 2   Google Cloud Platform (GCP)           NaN             NaN          NaN
# 3                            NaN          NaN             NaN          NaN
# 4                            NaN          NaN             NaN          NaN
#
#   Q27_B_Part_7 Q27_B_Part_8 Q27_B_Part_9  ... Q38_B_Part_3 Q38_B_Part_4  \
# ...

# %%
df_txt.drop("Unnamed: 0", axis= 1, inplace= True)
df_xml.drop("Unnamed: 0", axis= 1, inplace= True)
df_notebooks.drop("Unnamed: 0", axis= 1, inplace= True)

# %%
df_noprof.rename(columns= {"Unnamed: 0": "index"}, inplace= True)
df_platform.rename(columns= {"Unnamed: 0": "index"}, inplace= True)

# %%
df_noprof.set_index(["index"], inplace= True)
df_platform.set_index(["index"], inplace= True)

# %%
df_notebooks.head()
# Out:
#               Q10_kaggle        Q10_colab Q10_none
# index
# 0                    NaN  Colab Notebooks      NaN
# 1       Kaggle Notebooks  Colab Notebooks      NaN
# 2       Kaggle Notebooks              NaN      NaN
# 3                    NaN  Colab Notebooks      NaN
# 4                    NaN              NaN      NaN

# %%
df_xml.head(2)
# Out:
#          age gender
# index
# 0      50-54    Man
# 1      50-54    Man

# %%
df_xml.shape
# Out:
# (25973, 2)

# %%
df_txt.shape
# Out:
# (25973, 17)

# %%
df_txt.head(2)
# Out:
#             pais           estudios           puesto_trabajo experiencia  \
# index
# 0          India  Bachelor’s degree                    Other  5-10 years
# 1      Indonesia    Master’s degree  Program/Project Manager   20+ years
#
#       lenguaje_recomendado experiencia_ML                  industria  \
# index
# 0                   Python     5-10 years  Manufacturing/Fabrication
# 1                   Python       < 1 year  Manufacturing/Fabrication
#
#              tamaño_empresa        salario  \
# index
# 0          50-249 employees  25,000-29,999
# 1      1000-9,999 employees  60,000-69,999
#
#                                           herramienta_DA  lenguaje_utilizado  \
# index
# 0      Local development environments (RStudio, Jupyt...           Python, R
# 1        Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
#
#                                IDE  \
# index
# 0                      Vim / Emacs
# 1       Notepad++,Jupyter Notebook
#
# ...

# %%
df_join = df_xml.join(df_txt, on= "index").join(df_notebooks, on= "index").join(df_platform, on= "index").join(df_noprof, on= "index")
df_join.head()
# Out:
#          age gender       pais           estudios           puesto_trabajo  \
# index
# 0      50-54    Man      India  Bachelor’s degree                    Other
# 1      50-54    Man  Indonesia    Master’s degree  Program/Project Manager
# 2      22-24    Man   Pakistan    Master’s degree        Software Engineer
# 3      45-49    Man     Mexico    Doctoral degree       Research Scientist
# 4      45-49    Man      India    Doctoral degree                    Other
#
#       experiencia lenguaje_recomendado                         experiencia_ML  \
# index
# 0      5-10 years               Python                             5-10 years
# 1       20+ years               Python                               < 1 year
# 2       1-3 years               Python  I do not use machine learning methods
# 3       20+ years               Python                             5-10 years
# 4       < 1 years               Python                            10-20 years
#
# ...

# %%
df_join.shape
# Out:
# (25973, 150)

# %%
df_join.to_csv("../Archivos/union_datos.csv")

# %%
df_join.to_csv("../Limpieza/union_datos.csv")
