# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sidetable # si os da un error este comando es por no tenerlo instalado,

# %%
pd.options.display.max_columns = None

# %%
df = pd.read_csv('archivo_limpio.csv')
df.head(2)
# Out:
#     edad genero       pais           estudios           puesto_trabajo  \
# 0  50-54    Man      India  Bachelor’s degree                    Other
# 1  50-54    Man  Indonesia    Master’s degree  Program/Project Manager
#
#   experiencia lenguaje_recomendado experiencia_ML                  industria  \
# 0  5-10 years               Python     5-10 years  Manufacturing/Fabrication
# 1   20+ years               Python       < 1 year  Manufacturing/Fabrication
#
#          tamaño_empresa  salario  \
# 0      50-249 employees  30000.0
# 1  1000-9,999 employees  70000.0
#
#                                       herramienta_DA  lenguaje_utilizado  \
# 0  Local development environments (RStudio, Jupyt...           Python, R
# 1    Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
#
#                            IDE  \
# 0                  Vim / Emacs
# 1   Notepad++,Jupyter Notebook
#
#                           herramientas_visualizacion  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
# 1                                        Matplotlib
#
#                         Q16_frame_ml  \
# 0  Scikit-learn , TensorFlow ,Caret
# 1                      Scikit-learn
#
#                                           Q17_alg_ml Q32_prod_bigdata  \
# 0  Linear or Logistic Regression, Decision Trees ...      PostgreSQL
# 1  Linear or Logistic Regression, Decision Trees ...              NaN
#
#   Q34_herramientas_bi  Q28                      q10_notebooks  \
# 0                None  NaN                    Colab Notebooks
# 1                 NaN  NaN   Kaggle Notebooks,Colab Notebooks
#
#   q39_plat_compartir_trabajo  \
# 0           GitHub , Kaggle
# 1                        NaN
#
#                                      q40_plat_cursos  \
# 0  Coursera,edX,Kaggle Learn Courses,DataCamp,Uda...
# 1  Kaggle Learn Courses,Cloud-certification progr...
#
#               q27_plat_familiar_cloud_computing  \
# 0                                           NaN
# 1   Google Cloud Platform (GCP) , Oracle Cloud
#
#   q29b_productos_familiar_cloud_computing q31b_productos_familiar_ml  \
# 0                                     NaN                        NaN
# 1            Google Cloud Compute Engine                        None
#
#                           q32b_productos_familiar_bd  \
# 0                                                NaN
# 1  MySQL ,SQLite ,Oracle Database ,Google Cloud SQL
#
#   q34b_herramientas_familiar_bi  \
# 0                           NaN
# 1       Google Data Studio,Qlik
#
#                    q36b_cat_herramientas_familiar_ml  \
# 0                                                NaN
# 1  Automated model selection (e.g. auto-sklearn, ...
#
#   q37b_cat_herramientas_familiar_ml_aut q38b_herramientas_familiar_gest_exp_ml
# 0                                   NaN                                    NaN
# 1                  Google Cloud AutoML                                    None

# %%
def data_pregunta(dataf, colum):  # funcion para hacer df con la columna que queremos separar
    df = dataf[["edad", "genero", "pais", "estudios", "puesto_trabajo", "experiencia", "salario",colum]]
    df[colum] = df[colum].str.split(",")
    df = df.explode(colum)
    return df

df_plataforma =data_pregunta(df,'q39_plat_compartir_trabajo') # llamada a la función para hacer dataframe con la col q y otrs columnas relevantes
# Out:
# /tmp/ipykernel_3720/1658133390.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[colum] = df[colum].str.split(",")

# %% [markdown]
# -----------------------------------------------------------------------
# ### Plataformas para compartir trabajo Q39
# ----------------------------------

# %%
lista_ordenada = df_plataforma["q39_plat_compartir_trabajo"].value_counts().index.tolist() #para ordenar los resultados de la gráfica

# %%
plt.figure(figsize=(20,10))
fig = sns.countplot(y='q39_plat_compartir_trabajo',data=df_plataforma,order = lista_ordenada)

# %% [markdown]
# Se aprecia que la plataforma GitHub es la más utilizada. Llama la atención la gran cantidad de personas que no comparten su trabajo públicamente, en número similar a los que utilizan la plataforlma Kaggle. Google colab también está presente pero en menor medida.

# %%
# df con las cuatro plataformas más usadas
lista_plataformas = df_plataforma['q39_plat_compartir_trabajo'].value_counts()[:4].index.tolist()
lista_plataformas
# Out:
# [' GitHub ', 'I do not share my work publicly', ' Kaggle ', ' Colab ']

# %%
df_plat_mas = df_plataforma.loc[df_plataforma['q39_plat_compartir_trabajo'].isin(lista_plataformas)]
df_plat_mas['q39_plat_compartir_trabajo'].value_counts()
# Out:
#  GitHub                            4586
# I do not share my work publicly    3167
#  Kaggle                            3065
#  Colab                             1848
# Name: q39_plat_compartir_trabajo, dtype: int64

# %%
df_plat_mas
# Out:
#         edad genero                      pais           estudios  \
# 0      50-54    Man                     India  Bachelor’s degree
# 0      50-54    Man                     India  Bachelor’s degree
# 2      22-24    Man                  Pakistan    Master’s degree
# 4      45-49    Man                     India    Doctoral degree
# 7      30-34    Man                     India  Bachelor’s degree
# ...      ...    ...                       ...                ...
# 25963  60-69    Man  United States of America  Bachelor’s degree
# 25967  35-39    Man               South Korea  Bachelor’s degree
# 25967  35-39    Man               South Korea  Bachelor’s degree
# 25968  30-34    Man                     Egypt  Bachelor’s degree
# 25968  30-34    Man                     Egypt  Bachelor’s degree
#
#                 puesto_trabajo experiencia   salario  \
# 0                        Other  5-10 years   30000.0
# 0                        Other  5-10 years   30000.0
# 2            Software Engineer   1-3 years    1000.0
# 4                        Other   < 1 years   40000.0
# 7               Data Scientist  5-10 years   20000.0
# ...                        ...         ...       ...
# 25963  Program/Project Manager   20+ years  500000.0
# 25967        Software Engineer  5-10 years   90000.0
# 25967        Software Engineer  5-10 years   90000.0
# 25968             Data Analyst   1-3 years   20000.0
# 25968             Data Analyst   1-3 years   20000.0
#
#             q39_plat_compartir_trabajo
# 0                              GitHub
# 0                              Kaggle
# 2      I do not share my work publicly
# 4      I do not share my work publicly
# 7                              Kaggle
# ...                                ...
# 25963  I do not share my work publicly
# 25967                          GitHub
# 25967                           Colab
# 25968                          GitHub
# 25968                           Colab
#
# [12666 rows x 8 columns]

# %%
#Gráfica de Plataformas donde se comparte públicamente el trabajo
plt.figure(figsize=(10,8))
sns.countplot(x = 'q39_plat_compartir_trabajo', data = df_plat_mas)
plt.title(label = "Plataformas donde se comparte el trabajo")
plt.show()

# %% [markdown]
# ------------
# ### Plataformas donde se realizan Cursos Q40
# ----------

# %%
def data_pregunta(dataf, colum):  # funcion para hacer df con la columna que queremos separar
    df = dataf[["edad", "genero", "pais", "estudios", "puesto_trabajo", "experiencia", "salario",colum]]
    df[colum] = df[colum].str.split(",")
    df = df.explode(colum)
    return df

# %%
df_cursos =data_pregunta(df,'q40_plat_cursos')
df_cursos.head(2)
# Out:
# /tmp/ipykernel_3720/1325171681.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[colum] = df[colum].str.split(",")
#     edad genero   pais           estudios puesto_trabajo experiencia  salario  \
# 0  50-54    Man  India  Bachelor’s degree          Other  5-10 years  30000.0
# 0  50-54    Man  India  Bachelor’s degree          Other  5-10 years  30000.0
#
#   q40_plat_cursos
# 0        Coursera
# 0             edX

# %%
lista_columnas=["edad", "genero", "pais", "estudios", "puesto_trabajo", "experiencia", "salario"]

# %%
lista_cursos = df_cursos['q40_plat_cursos'].value_counts()[:4].index.tolist()
lista_cursos
# Out:
# ['Coursera',
#  'Kaggle Learn Courses',
#  'Udemy',
#  'University Courses (resulting in a university degree)']

# %%
df_cursos_mas = df_cursos.loc[df_cursos['q40_plat_cursos'].isin(lista_cursos)]
df_cursos_mas.head(2)
# Out:
#     edad genero   pais           estudios puesto_trabajo experiencia  salario  \
# 0  50-54    Man  India  Bachelor’s degree          Other  5-10 years  30000.0
# 0  50-54    Man  India  Bachelor’s degree          Other  5-10 years  30000.0
#
#         q40_plat_cursos
# 0              Coursera
# 0  Kaggle Learn Courses

# %%
#Gráfica de Plataformas donde se hacen cursos
plt.figure(figsize=(10,8))
sns.countplot(x = 'q40_plat_cursos', data =df_cursos_mas)
plt.title(label = "Plataformas donde se realizan cursos")
plt.show()

# %%
fig, axes = plt.subplots(2,2,figsize= (25,20))
axes = axes.flat
for indice, columna in enumerate(lista_columnas):
    sns.countplot(data = df_cursos_mas, x = "q40_plat_cursos", hue= columna, ax = axes[indice])
    axes[indice].set_title(f"Plataformas dende se realizan por {columna}")
fig.delaxes(axes[-1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_3720/1271751949.py in <module>
#       2 axes = axes.flat
#       3 for indice, columna in enumerate(lista_columnas):
# ----> 4     sns.countplot(data = df_cursos_mas, x = "q40_plat_cursos", hue= columna, ax = axes[indice])
#       5     axes[indice].set_title(f"Plataformas dende se realizan por {columna}")
#       6 fig.delaxes(axes[-1])
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %%
data_39_freq =df_plataforma.stb.freq(['q39_plat_compartir_trabajo'],thresh =90,other_label = 'otros')
data_39_freq
# Out:
#         q39_plat_compartir_trabajo  count    percent  cumulative_count  \
# 0                          GitHub    4586  30.990674              4586
# 1  I do not share my work publicly   3167  21.401541              7753
# 2                          Kaggle    3065  20.712258             10818
# 3                           Colab    1848  12.488174             12666
# 4                            otros   2132  14.407352             14798
#
#    cumulative_percent
# 0           30.990674
# 1           52.392215
# 2           73.104474
# 3           85.592648
# 4          100.000000

# %%
data_40_freq = df_cursos.stb.freq(['q40_plat_cursos'],thresh =60,other_label = 'otros')
data_40_freq
# Out:
#                                      q40_plat_cursos  count    percent  \
# 0                                           Coursera   9649  17.744635
# 1                               Kaggle Learn Courses   8670  15.944241
# 2                                              Udemy   6440  11.843243
# 3  University Courses (resulting in a university ...   4882   8.978061
# 4                                              otros  24736  45.489821
#
#    cumulative_count  cumulative_percent
# 0              9649           17.744635
# 1             18319           33.688876
# 2             24759           45.532118
# 3             29641           54.510179
# 4             54377          100.000000
