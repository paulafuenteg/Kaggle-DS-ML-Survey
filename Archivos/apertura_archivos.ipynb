# %%
import pandas as pd
import numpy as np

# %%
kaggle = pd.read_csv('data_remaning_kaggle.csv')
kaggle.head(10)
# Out:
#    Unnamed: 0  index                                         Q18_Part_1  \
# 0           0      0  General purpose image/video tools (PIL, cv2, s...
# 1           1      1                                                NaN
# 2           2      2                                                NaN
# 3           3      3  General purpose image/video tools (PIL, cv2, s...
# 4           4      4                                                NaN
# 5           5      5                                                NaN
# 6           6      6                                                NaN
# 7           7      7                                                NaN
# 8           8      8                                                NaN
# 9           9      9                                                NaN
#
#                                           Q18_Part_2  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
respuesta_q10= pd.read_csv('exported_db_data.csv')
respuesta_q10.head(10)
# Out:
#    index         Q10_Part_1       Q10_Part_2 Q10_Part_3 Q10_Part_4 Q10_Part_5  \
# 0      0                NaN  Colab Notebooks        NaN        NaN        NaN
# 1      1   Kaggle Notebooks  Colab Notebooks        NaN        NaN        NaN
# 2      2   Kaggle Notebooks              NaN        NaN        NaN        NaN
# 3      3                NaN  Colab Notebooks        NaN        NaN        NaN
# 4      4                NaN              NaN        NaN        NaN        NaN
# 5      5                NaN  Colab Notebooks        NaN        NaN        NaN
# 6      6   Kaggle Notebooks              NaN        NaN        NaN        NaN
# 7      7   Kaggle Notebooks              NaN        NaN        NaN        NaN
# 8      8   Kaggle Notebooks  Colab Notebooks        NaN        NaN        NaN
# 9      9   Kaggle Notebooks              NaN        NaN        NaN        NaN
#
#   Q10_Part_6 Q10_Part_7 Q10_Part_8 Q10_Part_9  \
# 0        NaN        NaN        NaN        NaN
# ...

# %%
data_xml = pd.read_xml('data_xml_clean.xml')
data_xml.head(10)
# Out:
#    level_0  index  time    age gender
# 0        0      0   910  50-54    Man
# 1        1      1   784  50-54    Man
# 2        2      2   924  22-24    Man
# 3        3      3   575  45-49    Man
# 4        4      4   781  45-49    Man
# 5        5      5  1020  25-29  Woman
# 6        6      6   141  18-21  Woman
# 7        7      7   484  30-34    Man
# 8        8      8  1744  22-24    Man
# 9        9      9   655  30-34    Man

# %%
data_txt = pd.read_csv('data_txt_clean.txt', sep =';')
data_txt.head(1)
# Out:
#    index     Q3                 Q4     Q5          Q6      Q8       Q11  \
# 0      0  India  Bachelor’s degree  Other  5-10 years  Python  A laptop
#
#          Q13         Q15                        Q20  ...  \
# 0  2-5 times  5-10 years  Manufacturing/Fabrication  ...
#
#                                                  Q41         Q7            Q9  \
# 0  Local development environments (RStudio, Jupyt...  Python, R   Vim / Emacs
#
#                   Q12                                                Q14  \
# 0  Google Cloud TPUs    Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
#
#                                  Q16  \
# 0  Scikit-learn , TensorFlow ,Caret
#
#                                                  Q17  \
# 0  Linear or Logistic Regression, Decision Trees ...
#
#                                                  Q24           Q32    Q34
# 0   None of these activities are an important par...   PostgreSQL    None
#
# [1 rows x 27 columns]

# %%
preguntas_txt  = data_txt.columns
preguntas_txt
# Out:
# Index(['index', 'Q3', 'Q4', 'Q5', 'Q6', 'Q8', 'Q11', 'Q13', 'Q15', 'Q20',
#        'Q21', 'Q22', 'Q23', 'Q25', 'Q26', 'Q33', 'Q35', 'Q41', 'Q7', 'Q9',
#        'Q12', 'Q14', 'Q16', 'Q17', 'Q24', 'Q32', 'Q34'],
#       dtype='object')
